# %% [markdown]
# ## Load the data:

# %%
import warnings
import numpy as np
import pandas as pd
import os

# Suppress specific UserWarnings from openpyxl
warnings.filterwarnings("ignore", category=UserWarning, module='openpyxl')

# Define the directory where your files are located
# data_dir = '.'  
data_dir = os.path.join(os.path.pardir)  

# List to hold the dataframes
dataframes = []

# Loop through the years and load the files
for year in range(2005, 2020):
    if year <= 2012:
        file_path = os.path.join(data_dir, f'{year}.xls')
    else:
        file_path = os.path.join(data_dir, f'{year}.xlsx')
    
    # Load the file into a dataframe
    df = pd.read_excel(file_path)
    
    # Append the dataframe to the list
    dataframes.append(df)

# Concatenate all the dataframes into one
betting_data = pd.concat(dataframes, ignore_index=True)

# Display the first few rows of the combined dataframe
betting_data.head()
# Out:
#    ATP  Location                  Tournament       Date         Series  \
# 0    1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 1    1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 2    1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 3    1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 4    1  Adelaide  Next Generation Hardcourts 2005-01-03  International
#
#      Court Surface      Round  Best of       Winner  ... UBW  UBL  LBW  LBL  \
# 0  Outdoor    Hard  1st Round        3  Saulnier C.  ... NaN  NaN  NaN  NaN
# 1  Outdoor    Hard  1st Round        3   Enqvist T.  ... NaN  NaN  NaN  NaN
# 2  Outdoor    Hard  1st Round        3    Melzer J.  ... NaN  NaN  NaN  NaN
# 3  Outdoor    Hard  1st Round        3    Rochus O.  ... NaN  NaN  NaN  NaN
# 4  Outdoor    Hard  1st Round        3     Mayer F.  ... NaN  NaN  NaN  NaN
#
#    SJW  SJL  MaxW MaxL AvgW AvgL
# 0  NaN  NaN   NaN  NaN  NaN  NaN
# 1  NaN  NaN   NaN  NaN  NaN  NaN
# 2  NaN  NaN   NaN  NaN  NaN  NaN
# 3  NaN  NaN   NaN  NaN  NaN  NaN
# 4  NaN  NaN   NaN  NaN  NaN  NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Fixing Anomalies

# %%
def is_column_numeric(df, column_name):
    # Check if the column contains only numeric values
    return df[column_name].apply(lambda x: str(x).isnumeric()).all()

# Check if columns are numeric before converting
anomaly_column = ['WRank', 'LRank', 'EXW']
for column in anomaly_column:
    if is_column_numeric(betting_data, column):
        print(f"Column '{column}' is numeric.\n")
    else:
        print(f"Column '{column}' is not numeric.\n")

def find_non_numeric_values(df, column_name):
    # Function to check if a value is numeric
    def is_numeric(value):
        try:
            float(value)
            return True
        except ValueError:
            return False

    # Apply the function to the column and filter non-numeric values
    non_numeric_values = df[~df[column_name].apply(is_numeric)]

    # Display the non-numeric values
    print(f"Non-numeric values in {column_name}:")
    print(non_numeric_values[[column_name]])

# WRank column
find_non_numeric_values(betting_data, 'WRank')

# LRank column
find_non_numeric_values(betting_data, 'LRank')

# EXW column
find_non_numeric_values(betting_data, 'EXW')
# Out:
# Column 'WRank' is not numeric.
#
# Column 'LRank' is not numeric.
#
# Column 'EXW' is not numeric.
#
# Non-numeric values in WRank:
# Empty DataFrame
# Columns: [WRank]
# Index: []
# Non-numeric values in LRank:
# Empty DataFrame
# Columns: [LRank]
# Index: []
# Non-numeric values in EXW:
#         EXW
# 23776  2.,3

# %%
# Convert WRank and LRank to numeric, coercing errors
betting_data['WRank'] = pd.to_numeric(betting_data['WRank'], errors='coerce')
betting_data['LRank'] = pd.to_numeric(betting_data['LRank'], errors='coerce')

# Fill NaN values with a high number
betting_data['WRank'].fillna(100000, inplace=True)
betting_data['LRank'].fillna(100000, inplace=True)

# Correct the typo in row 38294, column 'EXW'
if betting_data.at[38294, 'EXW'] == '2.,3':
    betting_data.at[38294, 'EXW'] = '2.3'

# %% [markdown]
# ## Feature Engineering:

# %%
# Now perform the calculations
betting_data['higher_rank_won'] = (betting_data['WRank'] < betting_data['LRank']).astype(int)
betting_data['higher_rank_points'] = betting_data['higher_rank_won'] * betting_data['WPts'] + betting_data['LPts'] * (1 - betting_data['higher_rank_won'])
betting_data['lower_rank_points'] = (1 - betting_data['higher_rank_won']) * betting_data['WPts'] + betting_data['LPts'] * betting_data['higher_rank_won']

# %%
# Ensure all columns are displayed
pd.set_option('display.max_columns', None)

# Display the DataFrame (or any part of it)
betting_data
# Out:
#        ATP  Location                  Tournament       Date         Series  \
# 0        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 1        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 2        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 3        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 4        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# ...    ...       ...                         ...        ...            ...
# 40385   66    London                 Masters Cup 2019-11-15    Masters Cup
# 40386   66    London                 Masters Cup 2019-11-15    Masters Cup
# 40387   66    London                 Masters Cup 2019-11-16    Masters Cup
# 40388   66    London                 Masters Cup 2019-11-16    Masters Cup
# 40389   66    London                 Masters Cup 2019-11-17    Masters Cup
#
#          Court Surface        Round  Best of         Winner          Loser  \
# 0      Outdoor    Hard    1st Round        3    Saulnier C.  Baccanello P.
# 1      Outdoor    Hard    1st Round        3     Enqvist T.     Sluiter R.
# 2      Outdoor    Hard    1st Round        3      Melzer J.     Berdych T.
# 3      Outdoor    Hard    1st Round        3      Rochus O.      Dupuis A.
# 4      Outdoor    Hard    1st Round        3       Mayer F.     Arthurs W.
# ...        ...     ...          ...      ...            ...            ...
# 40385   Indoor    Hard  Round Robin        3      Nadal R.   Tsitsipas S.
# 40386   Indoor    Hard  Round Robin        3     Zverev A.    Medvedev D.
# 40387   Indoor    Hard   Semifinals        3  Tsitsipas S.     Federer R.
# 40388   Indoor    Hard   Semifinals        3      Thiem D.      Zverev A.
# 40389   Indoor    Hard    The Final        3  Tsitsipas S.       Thiem D.
#
#        WRank  LRank    WPts    LPts   W1   L1   W2   L2   W3   L3  W4  L4  W5  \
# 0       53.0  324.0     NaN     NaN  6.0  2.0    7    6  NaN  NaN NaN NaN NaN
# 1       72.0   82.0     NaN     NaN  6.0  3.0    6    1  NaN  NaN NaN NaN NaN
# 2       39.0   45.0     NaN     NaN  6.0  4.0    4    6    7    6 NaN NaN NaN
# 3       66.0   79.0     NaN     NaN  6.0  3.0    3    6    6    1 NaN NaN NaN
# 4       35.0  101.0     NaN     NaN  6.0  4.0    3    6    7    5 NaN NaN NaN
# ...      ...    ...     ...     ...  ...  ...  ...  ...  ...  ...  ..  ..  ..
# 40385    1.0    6.0  9585.0  4000.0  6.0  7.0  6.0  4.0  7.0  5.0 NaN NaN NaN
# 40386    7.0    4.0  2945.0  5705.0  6.0  4.0  7.0  6.0  NaN  NaN NaN NaN NaN
# 40387    6.0    3.0  4000.0  6190.0  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN NaN
# 40388    5.0    7.0  5025.0  2945.0  7.0  5.0  6.0  3.0  NaN  NaN NaN NaN NaN
# 40389    6.0    5.0  4000.0  5025.0  6.0  7.0  6.0  2.0  7.0  6.0 NaN NaN NaN
#
#        L5  Wsets  Lsets    Comment  B365W  B365L   CBW  CBL  EXW   EXL   IWW  \
# 0     NaN    2.0    0.0  Completed  1.286  3.250  1.25  3.7  1.3  3.35  1.30
# 1     NaN    2.0    0.0  Completed  1.833  1.833  1.85  1.9  1.8  1.95  1.75
# 2     NaN    2.0    1.0  Completed  1.800  1.909  1.75  2.0  1.9  1.85  1.85
# 3     NaN    2.0    1.0  Completed  1.667  2.100  1.58  2.3  1.6  2.25  1.55
# 4     NaN    2.0    1.0  Completed  1.615  2.200  1.75  2.0  1.8  1.95  1.55
# ...    ..    ...    ...        ...    ...    ...   ...  ...  ...   ...   ...
# 40385 NaN    2.0    1.0  Completed  1.440  2.750   NaN  NaN  NaN   NaN   NaN
# 40386 NaN    2.0    0.0  Completed  1.900  1.900   NaN  NaN  NaN   NaN   NaN
# 40387 NaN    2.0    0.0  Completed  3.500  1.300   NaN  NaN  NaN   NaN   NaN
# 40388 NaN    2.0    0.0  Completed  1.800  2.000   NaN  NaN  NaN   NaN   NaN
# 40389 NaN    2.0    1.0  Completed  2.000  1.800   NaN  NaN  NaN   NaN   NaN
#
#         IWL    PSW    PSL  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0      2.70  1.305  3.780  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 1      1.75  1.990  1.840  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 2      1.65  1.901  1.917  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 3      2.00  1.621  2.410  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 4      2.00  1.787  2.070  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# ...     ...    ...    ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 40385   NaN  1.390  3.260  NaN  NaN  NaN  NaN  NaN  NaN  1.48  3.30  1.41
# 40386   NaN  2.140  1.790  NaN  NaN  NaN  NaN  NaN  NaN  2.24  2.06  1.92
# 40387   NaN  3.750  1.330  NaN  NaN  NaN  NaN  NaN  NaN  3.75  1.40  3.39
# 40388   NaN  1.840  2.100  NaN  NaN  NaN  NaN  NaN  NaN  1.87  2.20  1.78
# 40389   NaN  2.000  1.930  NaN  NaN  NaN  NaN  NaN  NaN  2.05  1.93  1.96
#
#        AvgL  higher_rank_won  higher_rank_points  lower_rank_points
# 0       NaN                1                 NaN                NaN
# 1       NaN                1                 NaN                NaN
# 2       NaN                1                 NaN                NaN
# 3       NaN                1                 NaN                NaN
# 4       NaN                1                 NaN                NaN
# ...     ...              ...                 ...                ...
# 40385  2.93                1              9585.0             4000.0
# 40386  1.90                0              5705.0             2945.0
# 40387  1.33                0              6190.0             4000.0
# 40388  2.06                1              5025.0             2945.0
# 40389  1.86                0              5025.0             4000.0
#
# [40390 rows x 51 columns]

# %% [markdown]
# ## Computing Missing Data using Mean

# %%
betting_data
# Out:
#        ATP  Location                  Tournament       Date         Series  \
# 0        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 1        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 2        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 3        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 4        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# ...    ...       ...                         ...        ...            ...
# 40385   66    London                 Masters Cup 2019-11-15    Masters Cup
# 40386   66    London                 Masters Cup 2019-11-15    Masters Cup
# 40387   66    London                 Masters Cup 2019-11-16    Masters Cup
# 40388   66    London                 Masters Cup 2019-11-16    Masters Cup
# 40389   66    London                 Masters Cup 2019-11-17    Masters Cup
#
#          Court Surface        Round  Best of         Winner          Loser  \
# 0      Outdoor    Hard    1st Round        3    Saulnier C.  Baccanello P.
# 1      Outdoor    Hard    1st Round        3     Enqvist T.     Sluiter R.
# 2      Outdoor    Hard    1st Round        3      Melzer J.     Berdych T.
# 3      Outdoor    Hard    1st Round        3      Rochus O.      Dupuis A.
# 4      Outdoor    Hard    1st Round        3       Mayer F.     Arthurs W.
# ...        ...     ...          ...      ...            ...            ...
# 40385   Indoor    Hard  Round Robin        3      Nadal R.   Tsitsipas S.
# 40386   Indoor    Hard  Round Robin        3     Zverev A.    Medvedev D.
# 40387   Indoor    Hard   Semifinals        3  Tsitsipas S.     Federer R.
# 40388   Indoor    Hard   Semifinals        3      Thiem D.      Zverev A.
# 40389   Indoor    Hard    The Final        3  Tsitsipas S.       Thiem D.
#
#        WRank  LRank    WPts    LPts   W1   L1   W2   L2   W3   L3  W4  L4  W5  \
# 0       53.0  324.0     NaN     NaN  6.0  2.0    7    6  NaN  NaN NaN NaN NaN
# 1       72.0   82.0     NaN     NaN  6.0  3.0    6    1  NaN  NaN NaN NaN NaN
# 2       39.0   45.0     NaN     NaN  6.0  4.0    4    6    7    6 NaN NaN NaN
# 3       66.0   79.0     NaN     NaN  6.0  3.0    3    6    6    1 NaN NaN NaN
# 4       35.0  101.0     NaN     NaN  6.0  4.0    3    6    7    5 NaN NaN NaN
# ...      ...    ...     ...     ...  ...  ...  ...  ...  ...  ...  ..  ..  ..
# 40385    1.0    6.0  9585.0  4000.0  6.0  7.0  6.0  4.0  7.0  5.0 NaN NaN NaN
# 40386    7.0    4.0  2945.0  5705.0  6.0  4.0  7.0  6.0  NaN  NaN NaN NaN NaN
# 40387    6.0    3.0  4000.0  6190.0  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN NaN
# 40388    5.0    7.0  5025.0  2945.0  7.0  5.0  6.0  3.0  NaN  NaN NaN NaN NaN
# 40389    6.0    5.0  4000.0  5025.0  6.0  7.0  6.0  2.0  7.0  6.0 NaN NaN NaN
#
#        L5  Wsets  Lsets    Comment  B365W  B365L   CBW  CBL  EXW   EXL   IWW  \
# 0     NaN    2.0    0.0  Completed  1.286  3.250  1.25  3.7  1.3  3.35  1.30
# 1     NaN    2.0    0.0  Completed  1.833  1.833  1.85  1.9  1.8  1.95  1.75
# 2     NaN    2.0    1.0  Completed  1.800  1.909  1.75  2.0  1.9  1.85  1.85
# 3     NaN    2.0    1.0  Completed  1.667  2.100  1.58  2.3  1.6  2.25  1.55
# 4     NaN    2.0    1.0  Completed  1.615  2.200  1.75  2.0  1.8  1.95  1.55
# ...    ..    ...    ...        ...    ...    ...   ...  ...  ...   ...   ...
# 40385 NaN    2.0    1.0  Completed  1.440  2.750   NaN  NaN  NaN   NaN   NaN
# 40386 NaN    2.0    0.0  Completed  1.900  1.900   NaN  NaN  NaN   NaN   NaN
# 40387 NaN    2.0    0.0  Completed  3.500  1.300   NaN  NaN  NaN   NaN   NaN
# 40388 NaN    2.0    0.0  Completed  1.800  2.000   NaN  NaN  NaN   NaN   NaN
# 40389 NaN    2.0    1.0  Completed  2.000  1.800   NaN  NaN  NaN   NaN   NaN
#
#         IWL    PSW    PSL  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0      2.70  1.305  3.780  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 1      1.75  1.990  1.840  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 2      1.65  1.901  1.917  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 3      2.00  1.621  2.410  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 4      2.00  1.787  2.070  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# ...     ...    ...    ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 40385   NaN  1.390  3.260  NaN  NaN  NaN  NaN  NaN  NaN  1.48  3.30  1.41
# 40386   NaN  2.140  1.790  NaN  NaN  NaN  NaN  NaN  NaN  2.24  2.06  1.92
# 40387   NaN  3.750  1.330  NaN  NaN  NaN  NaN  NaN  NaN  3.75  1.40  3.39
# 40388   NaN  1.840  2.100  NaN  NaN  NaN  NaN  NaN  NaN  1.87  2.20  1.78
# 40389   NaN  2.000  1.930  NaN  NaN  NaN  NaN  NaN  NaN  2.05  1.93  1.96
#
#        AvgL  higher_rank_won  higher_rank_points  lower_rank_points
# 0       NaN                1                 NaN                NaN
# 1       NaN                1                 NaN                NaN
# 2       NaN                1                 NaN                NaN
# 3       NaN                1                 NaN                NaN
# 4       NaN                1                 NaN                NaN
# ...     ...              ...                 ...                ...
# 40385  2.93                1              9585.0             4000.0
# 40386  1.90                0              5705.0             2945.0
# 40387  1.33                0              6190.0             4000.0
# 40388  2.06                1              5025.0             2945.0
# 40389  1.86                0              5025.0             4000.0
#
# [40390 rows x 51 columns]

# %%
# Define the column names for betting odds
betting_columns = ['CBW', 'CBL', 'IWW', 'IWL', 
                   'B365W', 'B365L', 'EXW', 'EXL', 
                   'PSW', 'PSL', 'UBW', 'UBL', 'LBW', 'LBL', 'SJW', 'SJL']

# Ensure all columns are numeric and convert if necessary
for col in betting_columns:
    if not pd.api.types.is_numeric_dtype(betting_data[col]):
        print(f"Converting column {col} to numeric.\n")
        betting_data[col] = pd.to_numeric(betting_data[col], errors='coerce')

# Display the number of missing values in the betting odds columns
missing_values_count = betting_data[betting_columns].isnull().sum()
print(f'Missing values in betting columns:\n{missing_values_count}\n')

# Calculate the mean of the available betting odds for each column
mean_betting_odds = betting_data[betting_columns].mean()
print(f'Mean of available betting odds:\n{mean_betting_odds}\n')

# Impute the missing values with the mean using .loc
for col in betting_columns:
    betting_data.loc[betting_data[col].isnull(), col] = mean_betting_odds[col]

# Verify that there are no more missing values
missing_values_count_after = betting_data[betting_columns].isnull().sum()
print(f'Missing values in betting columns after imputation:\n{missing_values_count_after}')
# Out:
# Converting column EXW to numeric.
#
# Missing values in betting columns:
# CBW      32337
# CBL      32337
# IWW      37571
# IWL      37571
# B365W      547
# B365L      524
# EXW       3611
# EXL       3605
# PSW       3150
# PSL       3150
# UBW      29719
# UBL      29719
# LBW      12259
# LBL      12248
# SJW      24818
# SJL      24811
# dtype: int64
#
# Mean of available betting odds:
# CBW      1.825494
# CBL      3.338149
# IWW      1.680738
# IWL      2.642355
# B365W    1.828470
# B365L    3.648420
# EXW      1.802534
# EXL      3.295159
# PSW      1.930257
# PSL      4.206489
# UBW      1.815867
# UBL      3.542479
# LBW      1.810226
# LBL      3.451461
# SJW      1.796538
# SJL      3.557943
# dtype: float64
#
# Missing values in betting columns after imputation:
# CBW      0
# CBL      0
# IWW      0
# IWL      0
# B365W    0
# B365L    0
# EXW      0
# EXL      0
# PSW      0
# PSL      0
# UBW      0
# UBL      0
# LBW      0
# LBL      0
# SJW      0
# SJL      0
# dtype: int64

# %% [markdown]
# ## Split the dataset

# %%
# Convert 'tourney_date' to datetime format 
betting_data['Date'] = pd.to_datetime(betting_data['Date'], format='%Y-%m-%d')

# Define the split date for January 1, 2019
split_time = pd.to_datetime('2019-01-01', format='%Y-%m-%d')

# Splitting the dataset into training and validation (test) sets
betting_data_2019 = betting_data[betting_data['Date'] >= split_time]
betting_data = betting_data[betting_data['Date'] < split_time]

# Create a copy of the dataset
betting_data_copy = betting_data.copy()
betting_data_2019_copy = betting_data_2019.copy()

# %% [markdown]
# ## BCM Model (2000 - 2018)

# %%
def process_betting_data(df, betting_columns):
    # Calculate raw implied probabilities
    for col in betting_columns:
        df.loc[:, f'implied_{col}'] = 1 / df[col]

    # Normalize the probabilities for each bookmaker
    for w_col, l_col in zip(betting_columns[::2], betting_columns[1::2]):
        df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
        df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])

    # Calculate logit values for normalized probabilities and then the consensus probability
    logit_cols = []
    for col in betting_columns[::2]:  # Process only the winner columns
        logit_col = f'logit_normalized_{col}'
        df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
        logit_cols.append(logit_col)

    # Calculate the average logit for consensus probability
    df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
    df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)

    # Create the probability of higher-ranked player winning
    df.loc[:, 'prob_higher_rank_winning'] = df.apply(
        lambda row: row['consensus_prob_W'] if row['higher_rank_won'] == 1 else (1 - row['consensus_prob_W']), axis=1
    )

    # Create the outcome column
    df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)

    return df

# %%
# Function to calculate logit
def logit(p):
    p = np.clip(p, 1e-10, 1 - 1e-10)  # Ensure probabilities are within (0, 1)
    return np.log(p / (1 - p))

# Function to calculate inverse logit
def inv_logit(y):
    return np.exp(y) / (1 + np.exp(y))

# %%
betting_data = process_betting_data(betting_data, betting_columns)
# Out:
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'prob_higher_rank_winning'] = df.apply(
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)

# %% [markdown]
# ## Evaluate Model Performance
# #### Accuracy:
# Calculate the accuracy of your model predictions.

# %%
accuracy_bcm = np.mean(betting_data.outcome == betting_data.higher_rank_won)
print(f'Accuracy: {accuracy_bcm}')
# Out:
# Accuracy: 0.8364420456649999

# %% [markdown]
# #### Calibration:
# Assess the calibration of your model.

# %%
# Calculate calibration
calibration_bcm = np.sum(betting_data.prob_higher_rank_winning) / np.sum(betting_data.higher_rank_won)
print(f'Calibration: {calibration_bcm}')
# Out:
# Calibration: 0.9286653821767712

# %% [markdown]
# ##### Log-loss:
# Compute the log-loss for your predictions.

# %%
def logloss(actual, predictions):
    epsilon = 1e-15
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    
    logr_logloss_all_predictors = -(1 / len(actual)) * np.sum(
        actual * np.log(predictions) + (1 - actual) * np.log(1 - predictions))
    return logr_logloss_all_predictors

# %%
logloss_bcm = logloss(betting_data.higher_rank_won, betting_data.prob_higher_rank_winning)
print(f'Logloss: {logloss_bcm}')
# Out:
# Logloss: 0.48797186839899886

# %%
betting_data
# Out:
#        ATP  Location                  Tournament       Date         Series  \
# 0        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 1        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 2        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 3        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 4        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# ...    ...       ...                         ...        ...            ...
# 37838    3      Pune            Maharashtra Open 2018-12-31         ATP250
# 37839    3      Pune            Maharashtra Open 2018-12-31         ATP250
# 37840    3      Pune            Maharashtra Open 2018-12-31         ATP250
# 37841    3      Pune            Maharashtra Open 2018-12-31         ATP250
# 37842    3      Pune            Maharashtra Open 2018-12-31         ATP250
#
#          Court Surface      Round  Best of       Winner               Loser  \
# 0      Outdoor    Hard  1st Round        3  Saulnier C.       Baccanello P.
# 1      Outdoor    Hard  1st Round        3   Enqvist T.          Sluiter R.
# 2      Outdoor    Hard  1st Round        3    Melzer J.          Berdych T.
# 3      Outdoor    Hard  1st Round        3    Rochus O.           Dupuis A.
# 4      Outdoor    Hard  1st Round        3     Mayer F.          Arthurs W.
# ...        ...     ...        ...      ...          ...                 ...
# 37838  Outdoor    Hard  1st Round        3    Darcis S.  Carballes Baena R.
# 37839  Outdoor    Hard  1st Round        3     Munar J.            Albot R.
# 37840  Outdoor    Hard  1st Round        3   Donskoy E.          Andujar P.
# 37841  Outdoor    Hard  1st Round        3      Mmoh M.      Gunneswaran P.
# 37842  Outdoor    Hard  1st Round        3    Gulbis E.            Sousa P.
#
#           WRank  LRank   WPts   LPts   W1   L1   W2   L2   W3   L3  W4  L4  \
# 0          53.0  324.0    NaN    NaN  6.0  2.0    7    6  NaN  NaN NaN NaN
# 1          72.0   82.0    NaN    NaN  6.0  3.0    6    1  NaN  NaN NaN NaN
# 2          39.0   45.0    NaN    NaN  6.0  4.0    4    6    7    6 NaN NaN
# 3          66.0   79.0    NaN    NaN  6.0  3.0    3    6    6    1 NaN NaN
# 4          35.0  101.0    NaN    NaN  6.0  4.0    3    6    7    5 NaN NaN
# ...         ...    ...    ...    ...  ...  ...  ...  ...  ...  ...  ..  ..
# 37838  100000.0   73.0    NaN  714.0  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN
# 37839      81.0   98.0  663.0  592.0  6.0  2.0  7.0  6.0  NaN  NaN NaN NaN
# 37840      97.0   82.0  594.0  658.0  6.0  3.0  5.0  7.0  7.0  6.0 NaN NaN
# 37841     103.0  110.0  563.0  521.0  7.0  5.0  6.0  3.0  NaN  NaN NaN NaN
# 37842      95.0  104.0  612.0  550.0  6.0  4.0  4.0  6.0  6.0  4.0 NaN NaN
#
#        W5  L5  Wsets  Lsets    Comment  B365W  B365L       CBW       CBL  \
# 0     NaN NaN    2.0    0.0  Completed  1.286  3.250  1.250000  3.700000
# 1     NaN NaN    2.0    0.0  Completed  1.833  1.833  1.850000  1.900000
# 2     NaN NaN    2.0    1.0  Completed  1.800  1.909  1.750000  2.000000
# 3     NaN NaN    2.0    1.0  Completed  1.667  2.100  1.580000  2.300000
# 4     NaN NaN    2.0    1.0  Completed  1.615  2.200  1.750000  2.000000
# ...    ..  ..    ...    ...        ...    ...    ...       ...       ...
# 37838 NaN NaN    2.0    0.0  Completed  2.370  1.530  1.825494  3.338149
# 37839 NaN NaN    2.0    0.0  Completed  2.000  1.720  1.825494  3.338149
# 37840 NaN NaN    2.0    1.0  Completed  1.500  2.500  1.825494  3.338149
# 37841 NaN NaN    2.0    0.0  Completed  1.660  2.100  1.825494  3.338149
# 37842 NaN NaN    2.0    1.0  Completed  1.330  3.250  1.825494  3.338149
#
#             EXW       EXL       IWW       IWL    PSW    PSL       UBW  \
# 0      1.300000  3.350000  1.300000  2.700000  1.305  3.780  1.815867
# 1      1.800000  1.950000  1.750000  1.750000  1.990  1.840  1.815867
# 2      1.900000  1.850000  1.850000  1.650000  1.901  1.917  1.815867
# 3      1.600000  2.250000  1.550000  2.000000  1.621  2.410  1.815867
# 4      1.800000  1.950000  1.550000  2.000000  1.787  2.070  1.815867
# ...         ...       ...       ...       ...    ...    ...       ...
# 37838  1.802534  3.295159  1.680738  2.642355  2.440  1.610  1.815867
# 37839  1.802534  3.295159  1.680738  2.642355  1.940  1.940  1.815867
# 37840  1.802534  3.295159  1.680738  2.642355  1.540  2.620  1.815867
# 37841  1.802534  3.295159  1.680738  2.642355  1.810  2.100  1.815867
# 37842  1.802534  3.295159  1.680738  2.642355  1.360  3.390  1.815867
#
#             UBL       LBW       LBL       SJW       SJL  MaxW  MaxL  AvgW  \
# 0      3.542479  1.810226  3.451461  1.796538  3.557943   NaN   NaN   NaN
# 1      3.542479  1.810226  3.451461  1.796538  3.557943   NaN   NaN   NaN
# 2      3.542479  1.810226  3.451461  1.796538  3.557943   NaN   NaN   NaN
# 3      3.542479  1.810226  3.451461  1.796538  3.557943   NaN   NaN   NaN
# 4      3.542479  1.810226  3.451461  1.796538  3.557943   NaN   NaN   NaN
# ...         ...       ...       ...       ...       ...   ...   ...   ...
# 37838  3.542479  1.810226  3.451461  1.796538  3.557943  2.47  1.65  2.35
# 37839  3.542479  1.810226  3.451461  1.796538  3.557943  2.08  1.95  1.94
# 37840  3.542479  1.810226  3.451461  1.796538  3.557943  1.57  2.65  1.51
# 37841  3.542479  1.810226  3.451461  1.796538  3.557943  1.83  2.17  1.74
# 37842  3.542479  1.810226  3.451461  1.796538  3.557943  1.40  3.50  1.35
#
#        AvgL  higher_rank_won  higher_rank_points  lower_rank_points  \
# 0       NaN                1                 NaN                NaN
# 1       NaN                1                 NaN                NaN
# 2       NaN                1                 NaN                NaN
# 3       NaN                1                 NaN                NaN
# 4       NaN                1                 NaN                NaN
# ...     ...              ...                 ...                ...
# 37838  1.59                0                 NaN                NaN
# 37839  1.86                1               663.0              592.0
# 37840  2.53                0               658.0              594.0
# 37841  2.09                1               563.0              521.0
# 37842  3.19                1               612.0              550.0
#
#        implied_CBW  implied_CBL  implied_IWW  implied_IWL  implied_B365W  \
# 0         0.800000     0.270270     0.769231     0.370370       0.777605
# 1         0.540541     0.526316     0.571429     0.571429       0.545554
# 2         0.571429     0.500000     0.540541     0.606061       0.555556
# 3         0.632911     0.434783     0.645161     0.500000       0.599880
# 0            0.279570        0.743363        0.256637        0.661114
# 1            0.480000        0.480418        0.519582        0.661114
# 2            0.506667        0.502095        0.497905        0.661114
# 3            0.415584        0.597867        0.402133        0.661114
# 4            0.480000        0.536687        0.463313        0.661114
# ...               ...             ...             ...             ...
# 37838        0.353598        0.397531        0.602469        0.661114
# 37839        0.353598        0.500000        0.500000        0.661114
# 37840        0.353598        0.629808        0.370192        0.661114
# 37841        0.353598        0.537084        0.462916        0.661114
# 37842        0.353598        0.713684        0.286316        0.661114
#
#        normalized_UBL  normalized_LBW  normalized_LBL  normalized_SJW  \
# 0            0.338886        0.655961        0.344039         0.66448
# 1            0.338886        0.655961        0.344039         0.66448
# 2            0.338886        0.655961        0.344039         0.66448
# 3            0.338886        0.655961        0.344039         0.66448
# 4            0.338886        0.655961        0.344039         0.66448
# ...               ...             ...             ...             ...
# 37838        0.338886        0.655961        0.344039         0.66448
# 37839        0.338886        0.655961        0.344039         0.66448
# 37840        0.338886        0.655961        0.344039         0.66448
# 37841        0.338886        0.655961        0.344039         0.66448
# 37842        0.338886        0.655961        0.344039         0.66448
#
#        normalized_SJL  logit_normalized_CBW  logit_normalized_IWW  \
# 0             0.33552              1.085189              0.730888
# 1             0.33552              0.026668              0.000000
# 2             0.33552              0.133531             -0.114410
# 3             0.33552              0.375484              0.254892
# 4             0.33552              0.133531              0.254892
# ...               ...                   ...                   ...
# 37838         0.33552              0.603566              0.452438
# 37839         0.33552              0.603566              0.452438
# 37840         0.33552              0.603566              0.452438
# 37841         0.33552              0.603566              0.452438
# 37842         0.33552              0.603566              0.452438
#
#        logit_normalized_B365W  logit_normalized_EXW  logit_normalized_PSW  \
# 0                    0.927118              0.946596              1.063521
# 1                    0.000000              0.080043             -0.078369
# 2                    0.058793             -0.026668              0.008381
# 3                    0.230912              0.340927              0.396584
# 4                    0.309122              0.080043              0.147010
# ...                       ...                   ...                   ...
# 37838               -0.437622              0.603261             -0.415764
# 37839               -0.150823              0.603261              0.000000
# 37840                0.510826              0.603261              0.531392
# 37841                0.235120              0.603261              0.148610
# 37842                0.893476              0.603261              0.913345
#
#        logit_normalized_UBW  logit_normalized_LBW  logit_normalized_SJW  \
# 0                  0.668264              0.645346              0.683321
# 1                  0.668264              0.645346              0.683321
# 2                  0.668264              0.645346              0.683321
# 3                  0.668264              0.645346              0.683321
# 4                  0.668264              0.645346              0.683321
# ...                     ...                   ...                   ...
# 37838              0.668264              0.645346              0.683321
# 37839              0.668264              0.645346              0.683321
# 37840              0.668264              0.645346              0.683321
# 37841              0.668264              0.645346              0.683321
# 37842              0.668264              0.645346              0.683321
#
#        consensus_logit_W  consensus_prob_W  prob_higher_rank_winning  outcome
# 0               0.843780          0.699261                  0.699261        1
# 1               0.253159          0.562954                  0.562954        1
# 2               0.257070          0.563916                  0.563916        1
# 3               0.449466          0.610512                  0.610512        1
# 4               0.365191          0.590297                  0.590297        1
# ...                  ...               ...                       ...      ...
# 37838           0.350351          0.586703                  0.413297        0
# 37839           0.438172          0.607823                  0.607823        1
# 37840           0.587302          0.642746                  0.357254        0
# 37841           0.504991          0.623631                  0.623631        1
# 37842           0.682877          0.664381                  0.664381        1
#
# [37797 rows x 95 columns]

# %% [markdown]
# ## BCM (2019)

# %%
# Define the column names for betting odds
betting_columns = ['B365W', 'B365L','PSW', 'PSL']

betting_data_2019 = process_betting_data(betting_data_2019, betting_columns)
# Out:
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'prob_higher_rank_winning'] = df.apply(
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\408763182.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)

# %% [markdown]
# ## Evaluate Model Performance

# %%
#Calculate Accuracy
accuracy_2019 = np.mean(betting_data_2019.outcome == betting_data_2019.higher_rank_won)
print(f'Accuracy: {accuracy_2019}')

# Calculate calibration
calibration_2019 = np.sum(betting_data_2019.prob_higher_rank_winning) / np.sum(betting_data_2019.higher_rank_won)
print(f'Calibration: {calibration_2019}')

# Calculate logloss
def logloss(actual, predictions):
    epsilon = 1e-15
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    
    logr_logloss_all_predictors = -(1 / len(actual)) * np.sum(
        actual * np.log(predictions) + (1 - actual) * np.log(1 - predictions))
    return logr_logloss_all_predictors

logloss_2019 = logloss(betting_data_2019.higher_rank_won, betting_data_2019.prob_higher_rank_winning)
print(f'Logloss: {logloss_2019}')
# Out:
# Accuracy: 0.6741226378711916
# Calibration: 1.0231932252529874
# Logloss: 0.5945646439823006

# %% [markdown]
# ## Extension 1:

# %%
import pandas as pd

# Load your dataset
df = betting_data_copy

# Filter dataset for top 50 and top 100 players
def filter_top_players(df, top_n):
    df_top = df[(df['WRank'] <= top_n) & (df['LRank'] <= top_n)]
    return df_top

df_top_50 = filter_top_players(df, 50)
df_top_100 = filter_top_players(df, 100)

# %%
#Calucate BCM
betting_columns = ['CBW', 'CBL', 'IWW', 'IWL', 
                   'B365W', 'B365L', 'EXW', 'EXL', 
                   'PSW', 'PSL', 'UBW', 'UBL', 'LBW', 'LBL', 'SJW', 'SJL']

def process_betting_data(df, betting_columns):
    # Calculate raw implied probabilities
    for col in betting_columns:
        df.loc[:, f'implied_{col}'] = 1 / df[col]

    # Normalize the probabilities for each bookmaker
    for w_col, l_col in zip(betting_columns[::2], betting_columns[1::2]):
        df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
        df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])

    # Calculate logit values for normalized probabilities and then the consensus probability
    logit_cols = []
    for col in betting_columns[::2]:  # Process only the winner columns
        logit_col = f'logit_normalized_{col}'
        df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
        logit_cols.append(logit_col)

    # Calculate the average logit for consensus probability
    df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
    df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)

    # Create the probability of higher-ranked player winning
    df.loc[:, 'prob_higher_rank_winning'] = df.apply(
        lambda row: row['consensus_prob_W'] if row['higher_rank_won'] == 1 else (1 - row['consensus_prob_W']), axis=1
    )

    # Create the outcome column
    df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)

    return df

# %%
df_top_50 = process_betting_data(df_top_50, betting_columns)
df_top_50
# Out:
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'prob_higher_rank_winning'] = df.apply(
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)
#        ATP  Location                  Tournament       Date         Series  \
# 2        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 19       1  Adelaide  Next Generation Hardcourts 2005-01-05  International
# 26       1  Adelaide  Next Generation Hardcourts 2005-01-07  International
# 27       1  Adelaide  Next Generation Hardcourts 2005-01-07  International
# 29       1  Adelaide  Next Generation Hardcourts 2005-01-08  International
# ...    ...       ...                         ...        ...            ...
# 37776   67    London                 Masters Cup 2018-11-16    Masters Cup
# 37777   67    London                 Masters Cup 2018-11-17    Masters Cup
# 37778   67    London                 Masters Cup 2018-11-17    Masters Cup
# 37779   67    London                 Masters Cup 2018-11-18    Masters Cup
# 37808    2      Doha      Qatar Exxon Mobil Open 2018-12-31         ATP250
#
#          Court Surface          Round  Best of        Winner        Loser  \
# 2      Outdoor    Hard      1st Round        3     Melzer J.   Berdych T.
# 19     Outdoor    Hard      2nd Round        3  Johansson J.   Malisse X.
# 26     Outdoor    Hard  Quarterfinals        3    Chela J.I.    Melzer J.
# 27     Outdoor    Hard  Quarterfinals        3       Dent T.    Hewitt L.
# 29     Outdoor    Hard     Semifinals        3       Dent T.   Chela J.I.
# ...        ...     ...            ...      ...           ...          ...
# 37776   Indoor    Hard    Round Robin        3   Djokovic N.     Cilic M.
# 37777   Indoor    Hard     Semifinals        3     Zverev A.   Federer R.
# 37778   Indoor    Hard     Semifinals        3   Djokovic N.  Anderson K.
# 37779   Indoor    Hard      The Final        3     Zverev A.  Djokovic N.
# 37808  Outdoor    Hard      1st Round        3      Jarry N.     Haase R.
#
#        WRank  LRank    WPts    LPts   W1   L1   W2   L2   W3   L3  W4  L4  W5  \
# 2       39.0   45.0     NaN     NaN  6.0  4.0    4    6    7    6 NaN NaN NaN
# 19      11.0   48.0     NaN     NaN  6.0  7.0    6    3    7    6 NaN NaN NaN
# 26      26.0   39.0     NaN     NaN  7.0  6.0    5    7    6    2 NaN NaN NaN
# 27      32.0    3.0     NaN     NaN  7.0  6.0    6    3  NaN  NaN NaN NaN NaN
# 29      32.0   26.0     NaN     NaN  6.0  1.0    6    1  NaN  NaN NaN NaN NaN
# ...      ...    ...     ...     ...  ...  ...  ...  ...  ...  ...  ..  ..  ..
# 37776    1.0    7.0  8045.0  4050.0  7.0  6.0  6.0  2.0  NaN  NaN NaN NaN NaN
# 37777    5.0    3.0  5085.0  6020.0  7.0  5.0  7.0  6.0  NaN  NaN NaN NaN NaN
# 37778    1.0    6.0  8045.0  4310.0  6.0  2.0  6.0  2.0  NaN  NaN NaN NaN NaN
# 37779    5.0    1.0  5085.0  8045.0  6.0  4.0  6.0  3.0  NaN  NaN NaN NaN NaN
# 37808   43.0   50.0  1022.0   965.0  6.0  7.0  6.0  4.0  7.0  6.0 NaN NaN NaN
#
#        L5  Wsets  Lsets    Comment  B365W  B365L       CBW       CBL  \
# 2     NaN    2.0    1.0  Completed   1.80  1.909  1.750000  2.000000
# 19    NaN    2.0    1.0  Completed   1.30  3.390  1.300000  3.400000
# 29           0.410256        0.578137        0.421863        0.661114
# ...               ...             ...             ...             ...
# 37776        0.177877        0.813375        0.186625        0.661114
# 37777        0.692641        0.303226        0.696774        0.661114
# 37778        0.140049        0.873303        0.126697        0.661114
# 37779        0.836820        0.154255        0.845745        0.661114
# 37808        0.353598        0.469231        0.530769        0.661114
#
#        normalized_UBL  normalized_LBW  normalized_LBL  normalized_SJW  \
# 2            0.338886        0.655961        0.344039         0.66448
# 19           0.338886        0.655961        0.344039         0.66448
# 26           0.338886        0.655961        0.344039         0.66448
# 27           0.338886        0.655961        0.344039         0.66448
# 29           0.338886        0.655961        0.344039         0.66448
# ...               ...             ...             ...             ...
# 37776        0.338886        0.655961        0.344039         0.66448
# 37777        0.338886        0.655961        0.344039         0.66448
# 37778        0.338886        0.655961        0.344039         0.66448
# 37779        0.338886        0.655961        0.344039         0.66448
# 37808        0.338886        0.655961        0.344039         0.66448
#
#        normalized_SJL  logit_normalized_CBW  logit_normalized_IWW  \
# 2             0.33552              0.133531             -0.114410
# 19            0.33552              0.961411              0.730888
# 26            0.33552              0.000000             -0.171850
# 27            0.33552             -1.728221             -1.195239
# 29            0.33552              0.362905              0.382992
# ...               ...                   ...                   ...
# 37776         0.33552              0.603566              0.452438
# 37777         0.33552              0.603566              0.452438
# 37778         0.33552              0.603566              0.452438
# 37779         0.33552              0.603566              0.452438
# 37808         0.33552              0.603566              0.452438
#
#        logit_normalized_B365W  logit_normalized_EXW  logit_normalized_PSW  \
# 2                    0.058793             -0.026668              0.008381
# 19                   0.958466              1.047040              0.975025
# 26                  -0.054067             -0.026668              0.104261
# 27                  -1.591419             -1.671131             -1.842312
# 29                   0.359855              0.362905              0.315130
# ...                       ...                   ...                   ...
# 37776                1.321756              1.530795              1.472090
# 37777               -0.855666             -0.812494             -0.831984
# 37778                1.841550              1.814882              1.930486
# 37779               -1.573720             -1.634756             -1.701608
# 37808               -0.235120              0.603261             -0.123233
#
#        logit_normalized_UBW  logit_normalized_LBW  logit_normalized_SJW  \
# 2                  0.668264              0.645346              0.683321
# 19                 0.668264              0.645346              0.683321
# 26                 0.668264              0.645346              0.683321
# 27                 0.668264              0.645346              0.683321
# 29                 0.668264              0.645346              0.683321
# ...                     ...                   ...                   ...
# 37776              0.668264              0.645346              0.683321
# 37777              0.668264              0.645346              0.683321
# 37778              0.668264              0.645346              0.683321
# 37779              0.668264              0.645346              0.683321
# 37808              0.668264              0.645346              0.683321
#
#        consensus_logit_W  consensus_prob_W  prob_higher_rank_winning  outcome
# 2               0.257070          0.563916                  0.563916        1
# 19              0.833720          0.697141                  0.697141        1
# 26              0.231076          0.557513                  0.557513        1
# 27             -0.753924          0.319967                  0.680033        1
# 29              0.472590          0.615997                  0.384003        0
# ...                  ...               ...                       ...      ...
# 37776           0.922197          0.715490                  0.715490        1
# 37777           0.069099          0.517268                  0.482732        0
# 37778           1.079982          0.746490                  0.746490        1
# 37779          -0.232144          0.442223                  0.557777        1
# 37808           0.412230          0.601623                  0.601623        1
#
# [9713 rows x 95 columns]

# %%
#Calculate Accuracy
accuracy_top_50 = np.mean(df_top_50.outcome == df_top_50.higher_rank_won)
print(f'Accuracy: {accuracy_top_50}')

# Calculate calibration
calibration_top_50 = np.sum(df_top_50.prob_higher_rank_winning) / np.sum(df_top_50.higher_rank_won)
print(f'Calibration: {calibration_top_50}')

# Calculate logloss
def logloss(actual, predictions):
    epsilon = 1e-15
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    
    logr_logloss_all_predictors = -(1 / len(actual)) * np.sum(
        actual * np.log(predictions) + (1 - actual) * np.log(1 - predictions))
    return logr_logloss_all_predictors

logloss_top_50 = logloss(df_top_50.higher_rank_won, df_top_50.prob_higher_rank_winning)
print(f'Logloss: {logloss_top_50}')
# Out:
# Accuracy: 0.8326984453824771
# Calibration: 0.9261544270653103
# Logloss: 0.49301020181382676

# %%
df_top_100 = process_betting_data(df_top_100, betting_columns)
df_top_100
# Out:
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'prob_higher_rank_winning'] = df.apply(
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)
#        ATP  Location                  Tournament       Date         Series  \
# 1        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 2        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 3        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 5        1  Adelaide  Next Generation Hardcourts 2005-01-03  International
# 6        1  Adelaide  Next Generation Hardcourts 2005-01-04  International
# ...    ...       ...                         ...        ...            ...
# 37811    2      Doha      Qatar Exxon Mobil Open 2018-12-31         ATP250
# 37812    2      Doha      Qatar Exxon Mobil Open 2018-12-31         ATP250
# 37813    2      Doha      Qatar Exxon Mobil Open 2018-12-31         ATP250
# 37839    3      Pune            Maharashtra Open 2018-12-31         ATP250
# 37840    3      Pune            Maharashtra Open 2018-12-31         ATP250
#
#          Court Surface      Round  Best of           Winner             Loser  \
# 1      Outdoor    Hard  1st Round        3       Enqvist T.        Sluiter R.
# 2      Outdoor    Hard  1st Round        3        Melzer J.        Berdych T.
# 3      Outdoor    Hard  1st Round        3        Rochus O.         Dupuis A.
# 5      Outdoor    Hard  1st Round        3        Kiefer N.       Schalken S.
# 6      Outdoor    Hard  1st Round        3       Malisse X.         Martin A.
# ...        ...     ...        ...      ...              ...               ...
# 37811  Outdoor    Hard  1st Round        3  Basilashvili N.  Ramos-Vinolas A.
# 37812  Outdoor    Hard  1st Round        3        Rublev A.          Seppi A.
# 37813  Outdoor    Hard  1st Round        3      Marterer M.      Gojowczyk P.
# 37839  Outdoor    Hard  1st Round        3         Munar J.          Albot R.
# 37840  Outdoor    Hard  1st Round        3       Donskoy E.        Andujar P.
#
#        WRank  LRank    WPts    LPts   W1   L1   W2   L2   W3   L3  W4  L4  W5  \
# 1       72.0   82.0     NaN     NaN  6.0  3.0    6    1  NaN  NaN NaN NaN NaN
# 2       39.0   45.0     NaN     NaN  6.0  4.0    4    6    7    6 NaN NaN NaN
# 3       66.0   79.0     NaN     NaN  6.0  3.0    3    6    6    1 NaN NaN NaN
# 5       21.0   57.0     NaN     NaN  6.0  2.0    2    1  NaN  NaN NaN NaN NaN
# 6       48.0   68.0     NaN     NaN  6.0  2.0    7    6  NaN  NaN NaN NaN NaN
# 37839     0.281061        0.646472        0.353528        0.611219
# 37840     0.281061        0.646472        0.353528        0.611219
#
#        normalized_IWL  normalized_B365W  normalized_B365L  normalized_EXW  \
# 1            0.500000          0.500000          0.500000        0.520000
# 2            0.528571          0.514694          0.485306        0.493333
# 3            0.436620          0.557473          0.442527        0.584416
# 5            0.378378          0.692361          0.307639        0.630923
# 6            0.397260          0.625000          0.375000        0.641975
# ...               ...               ...               ...             ...
# 37811        0.388781          0.662651          0.337349        0.646402
# 37812        0.388781          0.625000          0.375000        0.646402
# 37813        0.388781          0.486486          0.513514        0.646402
# 37839        0.388781          0.462366          0.537634        0.646402
# 37840        0.388781          0.625000          0.375000        0.646402
#
#        normalized_EXL  normalized_PSW  normalized_PSL  normalized_UBW  \
# 1            0.480000        0.480418        0.519582        0.661114
# 2            0.506667        0.502095        0.497905        0.661114
# 3            0.415584        0.597867        0.402133        0.661114
# 5            0.369077        0.687666        0.312334        0.661114
# 6            0.358025        0.617254        0.382746        0.661114
# ...               ...             ...             ...             ...
# 37811        0.353598        0.653488        0.346512        0.661114
# 37812        0.353598        0.656613        0.343387        0.661114
# 37813        0.353598        0.441624        0.558376        0.661114
# 37839        0.353598        0.500000        0.500000        0.661114
# 37840        0.353598        0.629808        0.370192        0.661114
#
#        normalized_UBL  normalized_LBW  normalized_LBL  normalized_SJW  \
# 1            0.338886        0.655961        0.344039         0.66448
# 2            0.338886        0.655961        0.344039         0.66448
# 3            0.338886        0.655961        0.344039         0.66448
# 5            0.338886        0.655961        0.344039         0.66448
# 6            0.338886        0.655961        0.344039         0.66448
# ...               ...             ...             ...             ...
# 37811        0.338886        0.655961        0.344039         0.66448
# 37812        0.338886        0.655961        0.344039         0.66448
# 37813        0.338886        0.655961        0.344039         0.66448
# 37839        0.338886        0.655961        0.344039         0.66448
# 37840        0.338886        0.655961        0.344039         0.66448
#
#        normalized_SJL  logit_normalized_CBW  logit_normalized_IWW  \
# 1             0.33552              0.026668              0.000000
# 2             0.33552              0.133531             -0.114410
# 3             0.33552              0.375484              0.254892
# 5             0.33552              0.791128              0.496437
# 6             0.33552              0.403340              0.416894
# ...               ...                   ...                   ...
# 37811         0.33552              0.603566              0.452438
# 37812         0.33552              0.603566              0.452438
# 37813         0.33552              0.603566              0.452438
# 37839         0.33552              0.603566              0.452438
# 37840         0.33552              0.603566              0.452438
#
#        logit_normalized_B365W  logit_normalized_EXW  logit_normalized_PSW  \
# 1                    0.000000              0.080043             -0.078369
# 2                    0.058793             -0.026668              0.008381
# 3                    0.230912              0.340927              0.396584
# 5                    0.811180              0.536177              0.789232
# 6                    0.510826              0.583948              0.477909
# ...                       ...                   ...                   ...
# 37811                0.675129              0.603261              0.634408
# 37812                0.510826              0.603261              0.648235
# 37813               -0.054067              0.603261             -0.234572
# 37839               -0.150823              0.603261              0.000000
# 37840                0.510826              0.603261              0.531392
#
#        logit_normalized_UBW  logit_normalized_LBW  logit_normalized_SJW  \
# 1                  0.668264              0.645346              0.683321
# 2                  0.668264              0.645346              0.683321
# 3                  0.668264              0.645346              0.683321
# 5                  0.668264              0.645346              0.683321
# 6                  0.668264              0.645346              0.683321
# ...                     ...                   ...                   ...
# 37811              0.668264              0.645346              0.683321
# 37812              0.668264              0.645346              0.683321
# 37813              0.668264              0.645346              0.683321
# 37839              0.668264              0.645346              0.683321
# 37840              0.668264              0.645346              0.683321
#
#        consensus_logit_W  consensus_prob_W  prob_higher_rank_winning  outcome
# 1               0.253159          0.562954                  0.562954        1
# 2               0.257070          0.563916                  0.563916        1
# 3               0.449466          0.610512                  0.610512        1
# 5               0.677636          0.663211                  0.663211        1
# 6               0.548731          0.633841                  0.633841        1
# ...                  ...               ...                       ...      ...
# 37811           0.620717          0.650382                  0.650382        1
# 37812           0.601907          0.646092                  0.353908        0
# 37813           0.420945          0.603709                  0.396291        0
# 37839           0.438172          0.607823                  0.607823        1
# 37840           0.587302          0.642746                  0.357254        0
#
# [24359 rows x 95 columns]

# %%
#Calculate Accuracy
accuracy_top_100 = np.mean(df_top_100.outcome == df_top_100.higher_rank_won)
print(f'Accuracy: {accuracy_top_100}')

# Calculate calibration
calibration_top_100 = np.sum(df_top_100.prob_higher_rank_winning) / np.sum(df_top_100.higher_rank_won)
print(f'Calibration: {calibration_top_100}')

# Calculate logloss
def logloss(actual, predictions):
    epsilon = 1e-15
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    
    logr_logloss_all_predictors = -(1 / len(actual)) * np.sum(
        actual * np.log(predictions) + (1 - actual) * np.log(1 - predictions))
    return logr_logloss_all_predictors

logloss_top_100 = logloss(df_top_100.higher_rank_won, df_top_100.prob_higher_rank_winning)
print(f'Logloss: {logloss_top_100}')
# Out:
# Accuracy: 0.8325875446446899
# Calibration: 0.9340747707662658
# Logloss: 0.49362619835701793

# %% [markdown]
# ### BCM : 2019

# %%
import pandas as pd

# Load your dataset
df_2019 = betting_data_2019_copy

# Filter dataset for top 50 and top 100 players
def filter_top_players(df, top_n):
    # Assuming you have a column 'rank' for player rankings
    df_top = df_2019[(df['WRank'] <= top_n) & (df['LRank'] <= top_n)]
    return df_top

df_top_50_2019 = filter_top_players(df_2019, 50)
df_top_100_2019 = filter_top_players(df_2019, 100)

# %%
# Define the column names for betting odds
betting_columns = ['B365W', 'B365L','PSW', 'PSL']

df_top_50_2019 = process_betting_data(df_top_50_2019, betting_columns)
df_top_100_2019 = process_betting_data(df_top_100_2019, betting_columns)
# Out:
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'prob_higher_rank_winning'] = df.apply(
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'implied_{col}'] = 1 / df[col]
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{w_col}'] = df[f'implied_{w_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f'normalized_{l_col}'] = df[f'implied_{l_col}'] / (df[f'implied_{w_col}'] + df[f'implied_{l_col}'])
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, logit_col] = df[f'normalized_{col}'].apply(logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_logit_W'] = df[logit_cols].mean(axis=1)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'consensus_prob_W'] = df['consensus_logit_W'].apply(inv_logit)
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'prob_higher_rank_winning'] = df.apply(
# C:\Users\niran\AppData\Local\Temp\ipykernel_27384\644679890.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'outcome'] = df['prob_higher_rank_winning'].apply(lambda x: 1 if x > 0.50 else 0)

# %%
#Calculate Accuracy
accuracy_top_50_2019 = np.mean(df_top_50_2019.outcome == df_top_50_2019.higher_rank_won)
print(f'Accuracy: {accuracy_top_50_2019}')

# Calculate calibration
calibration_top_50_2019 = np.sum(df_top_50_2019.prob_higher_rank_winning) / np.sum(df_top_50_2019.higher_rank_won)
print(f'Calibration: {calibration_top_50_2019}')

# Calculate logloss
def logloss(actual, predictions):
    epsilon = 1e-15
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    
    logr_logloss_all_predictors = -(1 / len(actual)) * np.sum(
        actual * np.log(predictions) + (1 - actual) * np.log(1 - predictions))
    return logr_logloss_all_predictors

logloss_top_50_2019 = logloss(df_top_50_2019.higher_rank_won, df_top_50_2019.prob_higher_rank_winning)
print(f'Logloss: {logloss_top_50_2019}')
# Out:
# Accuracy: 0.650381679389313
# Calibration: 1.041422052501375
# Logloss: 0.605936386676635

# %%
#Calculate Accuracy
accuracy_top_100_2019 = np.mean(df_top_100_2019.outcome == df_top_100_2019.higher_rank_won)
print(f'Accuracy: {accuracy_top_100_2019}')

# Calculate calibration
calibration_top_100_2019 = np.sum(df_top_100_2019.prob_higher_rank_winning) / np.sum(df_top_100_2019.higher_rank_won)
print(f'Calibration: {calibration_top_100_2019}')

# Calculate logloss
def logloss(actual, predictions):
    epsilon = 1e-15
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    
    logr_logloss_all_predictors = -(1 / len(actual)) * np.sum(
        actual * np.log(predictions) + (1 - actual) * np.log(1 - predictions))
    return logr_logloss_all_predictors

logloss_top_100_2019 = logloss(df_top_100_2019.higher_rank_won, df_top_100_2019.prob_higher_rank_winning)
print(f'Logloss: {logloss_top_100_2019}')
# Out:
# Accuracy: 0.6617142857142857
# Calibration: 1.034979269655389
# Logloss: 0.6065928952027444

# %%
# Create a DataFrame to store the validation statistics
validation_stats = pd.DataFrame({
    'model': [
        'BCM(2000-2018)', 'BCM(2019)',
        'BCM(2000-2018) Top 50', 'BCM(2000-2018) Top 100',
        'BCM(2019) Top 50', 'BCM(2019) Top 100'
    ],
    'accuracy': [
        accuracy_bcm, accuracy_2019,
        accuracy_top_50, accuracy_top_100,
        accuracy_top_50_2019, accuracy_top_100_2019
    ],
    'log_loss': [
        logloss_bcm, logloss_2019,
        logloss_top_50, logloss_top_100,
        logloss_top_50_2019, logloss_top_100_2019
    ],
    'calibration': [
        calibration_bcm, calibration_2019,
        calibration_top_50, calibration_top_100,
        calibration_top_50_2019, calibration_top_100_2019
    ]
})

# Print the validation statistics DataFrame
print(validation_stats)
# Out:
#                     model  accuracy  log_loss  calibration
# 0          BCM(2000-2018)  0.836442  0.487972     0.928665
# 1               BCM(2019)  0.674123  0.594565     1.023193
# 2   BCM(2000-2018) Top 50  0.832698  0.493010     0.926154
# 3  BCM(2000-2018) Top 100  0.832588  0.493626     0.934075
# 4        BCM(2019) Top 50  0.650382  0.605936     1.041422
# 5       BCM(2019) Top 100  0.661714  0.606593     1.034979
